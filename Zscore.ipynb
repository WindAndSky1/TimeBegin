# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.uniform(30,35,10)
y=np.random.uniform(20,24,10)
x1=(x-x.mean())/x.var()
y1=(y-y.mean())/y.var()
plt.scatter(x,y)
plt.scatter(x1,y1)
plt.show()
